# %%
#PANDAS Data Frames
import pandas as pd

#to generate random numbers
from numpy.random import randn

# %%
#create data frame size 5*5 containing random numbers
df = pd.DataFrame(randn(5,5),index=['ID1','ID2','ID3','ID4','ID5'],columns=['A1','A2','A3','A4','A5'])
df
# Out:
#            A1        A2        A3        A4        A5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2 -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID3 -1.185226 -1.771643  0.424658  0.308985  0.332167
# ID4 -0.897019  0.755111  1.482313  0.559335  0.153296
# ID5  0.522959  0.210999 -0.960521 -1.058445 -0.214742

# %% [markdown]
# # Change column and index names

# %%
#print columns and index
print(str(df.columns))
print(str(df.index))
# Out:
# Index(['A1', 'A2', 'A3', 'A4', 'A5'], dtype='object')
# Index(['ID1', 'ID2', 'ID3', 'ID4', 'ID5'], dtype='object')

# %%
#change columns
df.columns=['B1', 'B2', 'B3', 'B4', 'B5']
df
# Out:
#            B1        B2        B3        B4        B5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2 -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID3 -1.185226 -1.771643  0.424658  0.308985  0.332167
# ID4 -0.897019  0.755111  1.482313  0.559335  0.153296
# ID5  0.522959  0.210999 -0.960521 -1.058445 -0.214742

# %%
#change index
df.index=['First-ID', 'ID2', 'ID3', 'ID4', 'ID5']
#change columns
df.columns=['A1', 'A2', 'A3', 'A4', 'B5']
df
# Out:
#                 A1        A2        A3        A4        B5
# First-ID -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2      -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID3      -1.185226 -1.771643  0.424658  0.308985  0.332167
# ID4      -0.897019  0.755111  1.482313  0.559335  0.153296
# ID5       0.522959  0.210999 -0.960521 -1.058445 -0.214742

# %%
#Change just one column
df=df.rename(columns = {'B5':'A5'})

#Change just one index
df=df.rename(index = {'First-ID':'ID1'})
df
# Out:
#            A1        A2        A3        A4        A5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2 -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID3 -1.185226 -1.771643  0.424658  0.308985  0.332167
# ID4 -0.897019  0.755111  1.482313  0.559335  0.153296
# ID5  0.522959  0.210999 -0.960521 -1.058445 -0.214742

# %% [markdown]
# # Selection and Slicing

# %%
#Select values < 1
df_le1=df[df<0]
df_le1
#NaN=Not a Number
# Out:
#            A1        A2        A3        A4        A5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2 -0.981957       NaN       NaN       NaN -2.025169
# ID3 -1.185226 -1.771643       NaN       NaN       NaN
# ID4 -0.897019       NaN       NaN       NaN       NaN
# ID5       NaN       NaN -0.960521 -1.058445 -0.214742

# %%
#Drop NaN/missing values
df_le1.dropna()
# Out:
#            A1        A2        A3        A4       A5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.66244

# %%
df
# Out:
#            A1        A2        A3        A4        A5
# ID1 -1.029158 -0.164039 -1.306077 -0.685193 -1.662440
# ID2 -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID3 -1.185226 -1.771643  0.424658  0.308985  0.332167
# ID4 -0.897019  0.755111  1.482313  0.559335  0.153296
# ID5  0.522959  0.210999 -0.960521 -1.058445 -0.214742

# %%
# slice all rows, some columns 
df.loc[:, ['A2', 'A4']]
# Out:
#            A2        A4
# ID1 -0.164039 -0.685193
# ID2  0.558969  0.152791
# ID3 -1.771643  0.308985
# ID4  0.755111  0.559335
# ID5  0.210999 -1.058445

# %%
# slice all columns, some rows
df.loc[['ID2', 'ID4'], :]
# Out:
#            A1        A2        A3        A4        A5
# ID2 -0.981957  0.558969  1.646436  0.152791 -2.025169
# ID4 -0.897019  0.755111  1.482313  0.559335  0.153296

# %%
# slicing by index: iloc
#first column and row: index = 0
#last index in range can equal, but not exceed number of rows

df.iloc[1:5, 0:4]
# Out:
#            A1        A2        A3        A4
# ID2 -0.981957  0.558969  1.646436  0.152791
# ID3 -1.185226 -1.771643  0.424658  0.308985
# ID4 -0.897019  0.755111  1.482313  0.559335
# ID5  0.522959  0.210999 -0.960521 -1.058445

# %%
#last single index in range needs to be smaller than number of rows
#this works
print(df.iloc[4, 0:4])

#this does not work
df.iloc[5, 0:4]
# Out:
# A1    0.522959
# A2    0.210999
# A3   -0.960521
# A4   -1.058445
# Name: ID5, dtype: float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Akira\Desktop\HdM - IW\4. Semester\Introduction to Data Science\2. Python for Data Science\PYCRASH-PANDAS2.ipynb Cell 15 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Akira/Desktop/HdM%20-%20IW/4.%20Semester/Introduction%20to%20Data%20Science/2.%20Python%20for%20Data%20Science/PYCRASH-PANDAS2.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> print(df.iloc[4, 0:4])
#       <a href='vscode-notebook-cell:/c%3A/Users/Akira/Desktop/HdM%20-%20IW/4.%20Semester/Introduction%20to%20Data%20Science/2.%20Python%20for%20Data%20Science/PYCRASH-PANDAS2.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> #this does not work
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Akira/Desktop/HdM%20-%20IW/4.%20Semester/Introduction%20to%20Data%20Science/2.%20Python%20for%20Data%20Science/PYCRASH-PANDAS2.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> df.iloc[5, 0:4]
#
# File c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# File c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:904, in _LocationIndexer._validate_tuple_indexer(self, key)
#     902 for i, k in enumerate(key):
#     903     try:
# --> 904         self._validate_key(k, i)
#     905     except ValueError as err:
#     906         raise ValueError(
#     907             "Location based indexing can only have "
#     908             f"[{self._valid_types}] types"
#     909         ) from err
#
# File c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1496, in _iLocIndexer._validate_key(self, key, axis)
#    1494     return
#    1495 elif is_integer(key):
# -> 1496     self._validate_integer(key, axis)
#    1497 elif isinstance(key, tuple):
#    1498     # a tuple should already have been caught by this point
#    1499     # so don't treat a tuple as a valid indexer
#    1500     raise IndexingError("Too many indexers")
#
# File c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# slice all columns, some rows
df.iloc[[2,4], :]
# Out:
#            A1        A2        A3        A4        A5
# ID3 -1.390122 -0.972723 -1.849999  0.448481  0.037550
# ID5 -0.564465 -0.393990 -0.892170 -2.381591 -1.706757

# %%
# slice all rows, some columns
df.iloc[:, 2:4]
# Out:
#            A3        A4
# ID1  1.512490  0.953783
# ID2  0.787392 -0.904099
# ID3 -1.849999  0.448481
# ID4 -0.110447 -0.833851
# ID5 -0.892170 -2.381591

# %%
# slice with range closed to one side
df.iloc[:, :3]
# Out:
#            A1        A2        A3
# ID1 -0.122455 -2.089173  1.512490
# ID2  0.126913 -0.154748  0.787392
# ID3 -1.390122 -0.972723 -1.849999
# ID4  0.657815  0.134856 -0.110447
# ID5 -0.564465 -0.393990 -0.892170

# %%
#Combining positional and label-based indexing
#Single attribute
df.iloc[0:3, df.columns.get_loc('A2')]
# Out:
# ID1   -0.164039
# ID2    0.558969
# ID3   -1.771643
# Name: A2, dtype: float64

# %%
#Combining positional and label-based indexing
#Multiple attributes
df.iloc[[0, 2], df.columns.get_indexer(['A3', 'B4'])]
# Out:
#            A3        A5
# ID1  1.512490 -0.416236
# ID3 -1.849999  0.037550
