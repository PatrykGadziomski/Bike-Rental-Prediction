# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load planets dataset
planets_df = sns.load_dataset("planets")

#print shape of dataframe
print("Shape of data frame: ",planets_df.shape)
# Out:
# Shape of data frame:  (1035, 6)

# %%
#Show data frame
planets_df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#show descriptive statistics of this dataset
print(planets_df.describe())

#How many missing values can be expected for "orbital_period" based on the shape information and the descriptive statistics ?
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000
# 43

# %%
#calculate and show correlation matrix for orbital_period, mass and distance
corr = planets_df[["orbital_period", "mass", "distance"]].corr()
corr
# Out:
#                 orbital_period      mass  distance
# orbital_period        1.000000  0.173725 -0.034365
# mass                  0.173725  1.000000  0.274082
# distance             -0.034365  0.274082  1.000000

# %%
#draw Heatmap with correlations
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_dcace_row0_col0, #T_dcace_row1_col1, #T_dcace_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dcace_row0_col1, #T_dcace_row0_col2, #T_dcace_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dcace_row1_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_dcace_row1_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_dcace_row2_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dcace">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcace_level0_col0" class="col_heading level0 col0" >orbital_period</th>
#       <th id="T_dcace_level0_col1" class="col_heading level0 col1" >mass</th>
#       <th id="T_dcace_level0_col2" class="col_heading level0 col2" >distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcace_level0_row0" class="row_heading level0 row0" >orbital_period</th>
#       <td id="T_dcace_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dcace_row0_col1" class="data row0 col1" >0.173725</td>
#       <td id="T_dcace_row0_col2" class="data row0 col2" >-0.034365</td>
#     </tr>
#     <tr>
#       <th id="T_dcace_level0_row1" class="row_heading level0 row1" >mass</th>
#       <td id="T_dcace_row1_col0" class="data row1 col0" >0.173725</td>
#       <td id="T_dcace_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dcace_row1_col2" class="data row1 col2" >0.274082</td>
#     </tr>
#     <tr>
#       <th id="T_dcace_level0_row2" class="row_heading level0 row2" >distance</th>
#       <td id="T_dcace_row2_col0" class="data row2 col0" >-0.034365</td>
#       <td id="T_dcace_row2_col1" class="data row2 col1" >0.274082</td>
#       <td id="T_dcace_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#further investigate the correlation between the features in a scatter plot

#orbital period shall be plotted on x axis
#distance shall be plotted on y axis
#year shall be visualized through color 
#mass shall be represented by size ('s=')

scatter = planets_df.plot.scatter(x = 'orbital_period',
                                  y = 'distance',
                                  c = 'year',
                                  s = 'mass',
                                  colormap = 'viridis',
                                  sharex = False,)

# %%
#Analyze values for planet "mass" in a histogram with 15 bins
hist = planets_df['mass'].hist(bins=15, figsize=(10, 5))

#What is special about the shape of the distribution?

# %%
#Show combined boxplots for 'mass' and 'distance', but only for the first 500 rows of the dataset
boxplot = planets_df.iloc[:500, 3:5].boxplot(figsize=(10, 5))
#what is the problem with this boxplot?

# %%
#Now show the same data in separate boxplots
#boxplot_mass
boxplot = planets_df.iloc[:500, 3:4].boxplot(figsize=(10, 5))

# %%
#boxplot_distance
boxplot = planets_df.iloc[:500, 4:5].boxplot(figsize=(10, 5))
