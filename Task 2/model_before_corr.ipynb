# %%
# importing libraries
import pandas as pd
from sklearn import linear_model
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
from scipy import stats

# %%
# Loading the train and test data
train_df = pd.read_csv('../data/BikeRentalDaily_train.csv', delimiter=';')
test_df = pd.read_csv('../data/BikeRentalDaily_test.csv', delimiter=';')

# %%
# Minimal Preprocessing steps
# removing the 'dteday' feature
train_df = train_df.drop('dteday', axis=1).drop('instant', axis=1).drop('casual', axis=1).drop('registered', axis=1)
test_df = test_df.drop('dteday', axis=1).drop('instant', axis=1).drop('casual', axis=1).drop('registered', axis=1)

# %%
#calculate correlations between all features of your data frame (see Exploration lab)
train_corr = train_df.corr()
print(train_corr)

# Displaying correlations as a heatmap / correlation matrix 
train_corr.style.background_gradient(cmap='coolwarm')
# Out:
#                    season        yr      mnth   holiday   weekday  workingday  \
# season           1.000000 -0.030884  0.801076 -0.013694 -0.050261   -0.005155
# yr              -0.030884  1.000000 -0.028635  0.020713  0.058332    0.002573
# mnth             0.801076 -0.028635  1.000000  0.035361 -0.033016   -0.023682
# holiday         -0.013694  0.020713  0.035361  1.000000 -0.130308   -0.256362
# weekday         -0.050261  0.058332 -0.033016 -0.130308  1.000000    0.039966
# workingday      -0.005155  0.002573 -0.023682 -0.256362  0.039966    1.000000
# weathersit       0.026903 -0.041193  0.069314 -0.022176 -0.001078    0.073316
# temp             0.349176  0.034556  0.207133 -0.024204  0.013061    0.047687
# atemp            0.353616  0.033477  0.212783 -0.028545  0.004824    0.045879
# hum              0.222561 -0.114149  0.246345 -0.027229 -0.057230    0.034867
# windspeed       -0.165162  0.050415 -0.162857  0.019939 -0.057124    0.024044
# leaflets        -0.045326 -0.075728 -0.072537 -0.048536  0.066990    0.001663
# price reduction -0.015886 -0.006535 -0.030870 -0.046515 -0.059647    0.038023
# cnt              0.211559  0.358050  0.140144 -0.048029  0.129789   -0.040338
#
#                  weathersit      temp     atemp       hum  windspeed  \
# season             0.026903  0.349176  0.353616  0.222561  -0.165162
# yr                -0.041193  0.034556  0.033477 -0.114149   0.050415
# mnth               0.069314  0.207133  0.212783  0.246345  -0.162857
# holiday           -0.022176 -0.024204 -0.028545 -0.027229   0.019939
# weekday           -0.001078  0.013061  0.004824 -0.057230  -0.057124
# workingday         0.073316  0.047687  0.045879  0.034867   0.024044
# weathersit         1.000000 -0.096125 -0.096554  0.634391   0.077404
# temp              -0.096125  1.000000  0.990357  0.140084  -0.177135
# atemp             -0.096554  0.990357  1.000000  0.151166  -0.192152
# hum                0.634391  0.140084  0.151166  1.000000  -0.111199
# windspeed          0.077404 -0.177135 -0.192152 -0.111199   1.000000
# leaflets          -0.027512  0.014549  0.011986 -0.048554  -0.033478
# price reduction    0.041774 -0.019561 -0.015664 -0.030044   0.049203
# cnt               -0.184529  0.380473  0.383553 -0.078469  -0.100107
#
#                  leaflets  price reduction       cnt
# season          -0.045326        -0.015886  0.211559
# yr              -0.075728        -0.006535  0.358050
# mnth            -0.072537        -0.030870  0.140144
# holiday         -0.048536        -0.046515 -0.048029
# weekday          0.066990        -0.059647  0.129789
# workingday       0.001663         0.038023 -0.040338
# weathersit      -0.027512         0.041774 -0.184529
# temp             0.014549        -0.019561  0.380473
# atemp            0.011986        -0.015664  0.383553
# hum             -0.048554        -0.030044 -0.078469
# windspeed       -0.033478         0.049203 -0.100107
# leaflets         1.000000         0.081712  0.031955
# price reduction  0.081712         1.000000  0.008591
# cnt              0.031955         0.008591  1.000000
# <style type="text/css">
# #T_64896_row0_col0, #T_64896_row1_col1, #T_64896_row2_col2, #T_64896_row3_col3, #T_64896_row4_col4, #T_64896_row5_col5, #T_64896_row6_col6, #T_64896_row7_col7, #T_64896_row8_col8, #T_64896_row9_col9, #T_64896_row10_col10, #T_64896_row11_col11, #T_64896_row12_col12, #T_64896_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_64896_row0_col1, #T_64896_row2_col1, #T_64896_row3_col9, #T_64896_row7_col6, #T_64896_row8_col6, #T_64896_row11_col2, #T_64896_row12_col9, #T_64896_row13_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_64896_row0_col2, #T_64896_row2_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_64896_row0_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_64896_row0_col4, #T_64896_row5_col11, #T_64896_row10_col13 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_64896_row0_col5, #T_64896_row5_col8, #T_64896_row6_col2, #T_64896_row12_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_64896_row0_col6, #T_64896_row3_col10 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_64896_row0_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_64896_row0_col8, #T_64896_row1_col13 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_64896_row0_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_64896_row0_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_64896_row0_col11, #T_64896_row9_col12 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_64896_row0_col12, #T_64896_row8_col12, #T_64896_row10_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_64896_row0_col13, #T_64896_row9_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_64896_row1_col0, #T_64896_row1_col2, #T_64896_row3_col13, #T_64896_row6_col4, #T_64896_row12_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_64896_row1_col3, #T_64896_row10_col3, #T_64896_row10_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_64896_row1_col4, #T_64896_row4_col8, #T_64896_row6_col0, #T_64896_row11_col3, #T_64896_row12_col3, #T_64896_row13_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_64896_row1_col5, #T_64896_row1_col10, #T_64896_row11_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_64896_row1_col6, #T_64896_row3_col1, #T_64896_row5_col2, #T_64896_row8_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_64896_row1_col7, #T_64896_row5_col10, #T_64896_row8_col3, #T_64896_row9_col3, #T_64896_row11_col13 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_64896_row1_col8, #T_64896_row5_col7, #T_64896_row12_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_64896_row1_col9, #T_64896_row1_col11, #T_64896_row2_col11, #T_64896_row3_col4, #T_64896_row3_col5, #T_64896_row4_col12, #T_64896_row5_col3, #T_64896_row6_col13, #T_64896_row8_col10, #T_64896_row9_col1, #T_64896_row10_col0, #T_64896_row10_col2, #T_64896_row10_col7, #T_64896_row10_col8, #T_64896_row10_col9, #T_64896_row13_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_64896_row1_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_64896_row2_col3, #T_64896_row9_col5, #T_64896_row12_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_64896_row2_col4, #T_64896_row9_col13 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_64896_row2_col5, #T_64896_row6_col3, #T_64896_row7_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_64896_row2_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_64896_row2_col7 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_64896_row2_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_64896_row2_col9, #T_64896_row8_col2, #T_64896_row13_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_64896_row2_col10, #T_64896_row2_col12, #T_64896_row3_col11, #T_64896_row9_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_64896_row2_col13 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_64896_row3_col0, #T_64896_row3_col7, #T_64896_row4_col11, #T_64896_row8_col1, #T_64896_row11_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_64896_row3_col2, #T_64896_row11_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_64896_row3_col6, #T_64896_row3_col8, #T_64896_row5_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_64896_row3_col12, #T_64896_row7_col10 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_64896_row4_col0, #T_64896_row4_col3, #T_64896_row13_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_64896_row4_col1, #T_64896_row4_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_64896_row4_col2, #T_64896_row4_col10 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_64896_row4_col5, #T_64896_row8_col9 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_64896_row4_col7, #T_64896_row11_col7, #T_64896_row12_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_64896_row4_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_64896_row4_col13, #T_64896_row6_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_64896_row5_col1, #T_64896_row10_col12, #T_64896_row11_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_64896_row5_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_64896_row5_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_64896_row5_col9, #T_64896_row7_col1, #T_64896_row11_col10, #T_64896_row11_col12, #T_64896_row12_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_64896_row5_col12 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_64896_row5_col13 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_64896_row6_col1, #T_64896_row9_col4, #T_64896_row10_col4, #T_64896_row12_col4, #T_64896_row13_col12 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_64896_row6_col7, #T_64896_row9_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_64896_row6_col8, #T_64896_row8_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_64896_row6_col9 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_64896_row6_col10, #T_64896_row10_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_64896_row6_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_64896_row6_col12, #T_64896_row12_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_64896_row7_col0, #T_64896_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_64896_row7_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_64896_row7_col4, #T_64896_row12_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_64896_row7_col5, #T_64896_row8_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_64896_row7_col8, #T_64896_row8_col7 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_64896_row7_col9, #T_64896_row13_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_64896_row7_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_64896_row7_col12 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_64896_row7_col13, #T_64896_row8_col13 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_64896_row9_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_64896_row9_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_64896_row9_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_64896_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_64896_row10_col1, #T_64896_row12_col8, #T_64896_row12_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_64896_row11_col1, #T_64896_row13_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_64896_row11_col4, #T_64896_row13_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_64896_row11_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_64896_row13_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_64896_row13_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_64896_row13_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_64896_row13_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# </style>
# <table id="T_64896">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>

# %%
#calculate correlations of features to label
train_df_corr_label = train_df.iloc[:, :].corr()["cnt"]
train_df_corr_label
# Out:
# season             0.211559
# yr                 0.358050
# mnth               0.140144
# holiday           -0.048029
# weekday            0.129789
# workingday        -0.040338
# weathersit        -0.184529
# temp               0.380473
# atemp              0.383553
# hum               -0.078469
# windspeed         -0.100107
# leaflets           0.031955
# price reduction    0.008591
# cnt                1.000000
# Name: cnt, dtype: float64

# %%
train_df_1 = train_df[train_df_corr_label.abs().sort_values(ascending=False).index[:7]]
train_df_1
# Out:
#       cnt     atemp     temp  yr  season  weathersit  mnth
# 0    5312  0.587133  24.8000   0     2.0           1     6
# 1    5445  0.324492  12.8667   1     4.0           2    11
# 2    2236  0.126275   6.0000   1     1.0           1     1
# 3    6370  0.614925  26.5667   1     2.0           1     4
# 4    7836  0.505046  20.5667   1     1.0           2     3
# ..    ...       ...      ...  ..     ...         ...   ...
# 595  3117  0.466525  18.9000   0     1.0           1     3
# 596  2703  0.440642  17.6667   0     NaN           1     3
# 597  4097  0.381938  15.3000   1     1.0           2     1
# 598  3894  0.472846  19.3667   0     4.0           2    10
# 599  7030  0.520833  21.3333   1     2.0           1     5
#
# [600 rows x 7 columns]

# %%
#calculate correlations between all features of your data frame (see Exploration lab)
test_corr = test_df.corr()
print(train_corr)

# Displaying correlations as a heatmap / correlation matrix 
test_corr.style.background_gradient(cmap='coolwarm')
# Out:
#                    season        yr      mnth   holiday   weekday  workingday  \
# season           1.000000 -0.030884  0.801076 -0.013694 -0.050261   -0.005155
# yr              -0.030884  1.000000 -0.028635  0.020713  0.058332    0.002573
# mnth             0.801076 -0.028635  1.000000  0.035361 -0.033016   -0.023682
# holiday         -0.013694  0.020713  0.035361  1.000000 -0.130308   -0.256362
# weekday         -0.050261  0.058332 -0.033016 -0.130308  1.000000    0.039966
# workingday      -0.005155  0.002573 -0.023682 -0.256362  0.039966    1.000000
# weathersit       0.026903 -0.041193  0.069314 -0.022176 -0.001078    0.073316
# temp             0.349176  0.034556  0.207133 -0.024204  0.013061    0.047687
# atemp            0.353616  0.033477  0.212783 -0.028545  0.004824    0.045879
# hum              0.222561 -0.114149  0.246345 -0.027229 -0.057230    0.034867
# windspeed       -0.165162  0.050415 -0.162857  0.019939 -0.057124    0.024044
# leaflets        -0.045326 -0.075728 -0.072537 -0.048536  0.066990    0.001663
# price reduction -0.015886 -0.006535 -0.030870 -0.046515 -0.059647    0.038023
# cnt              0.211559  0.358050  0.140144 -0.048029  0.129789   -0.040338
#
#                  weathersit      temp     atemp       hum  windspeed  \
# season             0.026903  0.349176  0.353616  0.222561  -0.165162
# yr                -0.041193  0.034556  0.033477 -0.114149   0.050415
# mnth               0.069314  0.207133  0.212783  0.246345  -0.162857
# holiday           -0.022176 -0.024204 -0.028545 -0.027229   0.019939
# weekday           -0.001078  0.013061  0.004824 -0.057230  -0.057124
# workingday         0.073316  0.047687  0.045879  0.034867   0.024044
# weathersit         1.000000 -0.096125 -0.096554  0.634391   0.077404
# temp              -0.096125  1.000000  0.990357  0.140084  -0.177135
# atemp             -0.096554  0.990357  1.000000  0.151166  -0.192152
# hum                0.634391  0.140084  0.151166  1.000000  -0.111199
# windspeed          0.077404 -0.177135 -0.192152 -0.111199   1.000000
# leaflets          -0.027512  0.014549  0.011986 -0.048554  -0.033478
# price reduction    0.041774 -0.019561 -0.015664 -0.030044   0.049203
# cnt               -0.184529  0.380473  0.383553 -0.078469  -0.100107
#
#                  leaflets  price reduction       cnt
# season          -0.045326        -0.015886  0.211559
# yr              -0.075728        -0.006535  0.358050
# mnth            -0.072537        -0.030870  0.140144
# holiday         -0.048536        -0.046515 -0.048029
# weekday          0.066990        -0.059647  0.129789
# workingday       0.001663         0.038023 -0.040338
# weathersit      -0.027512         0.041774 -0.184529
# temp             0.014549        -0.019561  0.380473
# atemp            0.011986        -0.015664  0.383553
# hum             -0.048554        -0.030044 -0.078469
# windspeed       -0.033478         0.049203 -0.100107
# leaflets         1.000000         0.081712  0.031955
# price reduction  0.081712         1.000000  0.008591
# cnt              0.031955         0.008591  1.000000
# <style type="text/css">
# #T_7f271_row0_col0, #T_7f271_row1_col1, #T_7f271_row2_col2, #T_7f271_row3_col3, #T_7f271_row4_col4, #T_7f271_row5_col5, #T_7f271_row6_col6, #T_7f271_row7_col7, #T_7f271_row7_col8, #T_7f271_row8_col7, #T_7f271_row8_col8, #T_7f271_row9_col9, #T_7f271_row10_col10, #T_7f271_row11_col11, #T_7f271_row12_col12, #T_7f271_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col1, #T_7f271_row0_col6, #T_7f271_row1_col2, #T_7f271_row1_col5, #T_7f271_row1_col9, #T_7f271_row1_col12, #T_7f271_row3_col12, #T_7f271_row13_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col3, #T_7f271_row10_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col4, #T_7f271_row0_col10, #T_7f271_row11_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col5, #T_7f271_row9_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_7f271_row0_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_7f271_row0_col8 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7f271_row0_col9 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_7f271_row0_col11, #T_7f271_row10_col5, #T_7f271_row12_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col12 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7f271_row0_col13 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7f271_row1_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col3, #T_7f271_row3_col13, #T_7f271_row8_col10, #T_7f271_row9_col5, #T_7f271_row9_col13, #T_7f271_row13_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col4, #T_7f271_row3_col5, #T_7f271_row5_col3, #T_7f271_row6_col1, #T_7f271_row6_col7, #T_7f271_row6_col8, #T_7f271_row6_col12, #T_7f271_row6_col13, #T_7f271_row8_col6, #T_7f271_row9_col10, #T_7f271_row10_col0, #T_7f271_row10_col2, #T_7f271_row10_col9, #T_7f271_row10_col11, #T_7f271_row13_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col6, #T_7f271_row10_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col7, #T_7f271_row1_col8, #T_7f271_row7_col9, #T_7f271_row12_col13 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_7f271_row1_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col11, #T_7f271_row4_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_7f271_row1_col13 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_7f271_row2_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col1, #T_7f271_row4_col12 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col3, #T_7f271_row2_col6, #T_7f271_row3_col7, #T_7f271_row3_col8, #T_7f271_row10_col7, #T_7f271_row11_col0, #T_7f271_row11_col5, #T_7f271_row12_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col4, #T_7f271_row3_col1, #T_7f271_row3_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col5, #T_7f271_row5_col0, #T_7f271_row7_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_7f271_row2_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_7f271_row2_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_7f271_row2_col9 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_7f271_row2_col10, #T_7f271_row7_col3, #T_7f271_row7_col4, #T_7f271_row8_col3, #T_7f271_row8_col4, #T_7f271_row9_col11, #T_7f271_row13_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col11, #T_7f271_row3_col0, #T_7f271_row3_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col12, #T_7f271_row6_col11, #T_7f271_row7_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7f271_row2_col13 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_7f271_row3_col2, #T_7f271_row7_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7f271_row3_col9, #T_7f271_row4_col5, #T_7f271_row11_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7f271_row3_col10, #T_7f271_row8_col1, #T_7f271_row10_col6, #T_7f271_row10_col13, #T_7f271_row11_col12 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_7f271_row3_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7f271_row4_col0, #T_7f271_row7_col10, #T_7f271_row11_col7, #T_7f271_row11_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7f271_row4_col1, #T_7f271_row5_col11 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_7f271_row4_col3, #T_7f271_row5_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_7f271_row4_col6, #T_7f271_row5_col7, #T_7f271_row9_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_7f271_row4_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_7f271_row4_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7f271_row4_col9, #T_7f271_row5_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_7f271_row4_col10, #T_7f271_row5_col12, #T_7f271_row7_col12, #T_7f271_row9_col2, #T_7f271_row12_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7f271_row4_col11, #T_7f271_row8_col5, #T_7f271_row9_col8, #T_7f271_row11_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_7f271_row4_col13, #T_7f271_row12_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_7f271_row5_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_7f271_row5_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_7f271_row5_col4, #T_7f271_row12_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_7f271_row5_col8, #T_7f271_row8_col12, #T_7f271_row9_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7f271_row5_col9, #T_7f271_row12_col11 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_7f271_row5_col10 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_7f271_row6_col0, #T_7f271_row6_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_7f271_row6_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7f271_row6_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7f271_row6_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7f271_row6_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_7f271_row6_col10, #T_7f271_row13_col4, #T_7f271_row13_col10, #T_7f271_row13_col12 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7f271_row7_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_7f271_row7_col2, #T_7f271_row12_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_7f271_row7_col11, #T_7f271_row8_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_7f271_row7_col13, #T_7f271_row13_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_7f271_row8_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_7f271_row8_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7f271_row8_col9 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7f271_row8_col13, #T_7f271_row13_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_7f271_row9_col1, #T_7f271_row9_col4, #T_7f271_row11_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7f271_row9_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_7f271_row9_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7f271_row10_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7f271_row10_col8, #T_7f271_row12_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_7f271_row10_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7f271_row11_col3, #T_7f271_row11_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_7f271_row11_col4, #T_7f271_row12_col0, #T_7f271_row12_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_7f271_row11_col13 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7f271_row12_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_7f271_row12_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7f271_row13_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_7f271_row13_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7f271_row13_col2 {
#   background-c

# %%
#calculate correlations of features to label
test_df_corr_label = train_df.iloc[:, :].corr()["cnt"]
test_df_corr_label
# Out:
# season             0.211559
# yr                 0.358050
# mnth               0.140144
# holiday           -0.048029
# weekday            0.129789
# workingday        -0.040338
# weathersit        -0.184529
# temp               0.380473
# atemp              0.383553
# hum               -0.078469
# windspeed         -0.100107
# leaflets           0.031955
# price reduction    0.008591
# cnt                1.000000
# Name: cnt, dtype: float64

# %%
test_df_1 = test_df[test_df_corr_label.abs().sort_values(ascending=False).index[:7]]
test_df_1
# Out:
#       cnt     atemp     temp  yr  season  weathersit  mnth
# 0    3894  0.472846  19.3667   0     4.0           2    10
# 1    5936  0.427513  17.3565   1     2.0           1     4
# 2    5629  0.326383  13.0000   1     4.0           1    11
# 3    3310  0.270196   9.5333   0     4.0           1    12
# 4    4748  0.522721  21.3000   0     4.0           2    10
# ..    ...       ...      ...  ..     ...         ...   ...
# 127  4990  0.475371  19.4333   1     1.0           1     3
# 128  5687  0.687508  30.6000   1     3.0           1     6
# 129  3907  0.575158  25.4000   0     4.0           2     9
# 130  5225  0.654688  29.1333   0     3.0           1     6
# 131  1977  0.162250   6.5000   1     1.0           2     1
#
# [132 rows x 7 columns]

# %%
# Replacing all MissingValues with the most frequent values
imp_most_freq = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

train_df_1[:] = imp_most_freq.fit_transform(train_df_1)
test_df_1[:] = imp_most_freq.fit_transform(test_df_1)
# Out:
# C:\Users\Akira\AppData\Local\Temp\ipykernel_3396\2519801057.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_1[:] = imp_most_freq.fit_transform(train_df_1)
# C:\Users\Akira\AppData\Local\Temp\ipykernel_3396\2519801057.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_1[:] = imp_most_freq.fit_transform(test_df_1)

# %%
# train test aplit

train_features = train_df_1.iloc[:, 1:]
train_labels = train_df_1.iloc[:, :1]

test_features = test_df_1.iloc[:, 1:]
test_labels = test_df_1.iloc[:, :1]

# %%
# Model building
reg_model_before_pp = linear_model.LinearRegression()

reg_model_before_pp.fit(train_features, train_labels)

print(reg_model_before_pp.coef_)
# Out:
# [[ 7.06848983e+03  3.17670316e+00  2.47496949e+03  2.96340462e+02
#   -9.52774594e+02  2.82119368e+01]]

# %%
# Predict all test examples
ypred = reg_model_before_pp.predict(test_features)
ypred
# Out:
# array([[3505.50991795],
#        [5844.47980062],
#        [5905.96859876],
#        [3051.04112903],
#        [3864.1923684 ],
#        [1277.86527256],
#        [7977.17576614],
#        [6261.89801325],
#        [5484.15717911],
#        [6050.2110409 ],
#        [5159.69517143],
#        [7606.29537727],
#        [2118.70746289],
#        [8442.02141818],
#        [7010.26207478],
#        [7984.69146087],
#        [7949.3907678 ],
#        [3179.51729579],
#        [5443.46898288],
#        [8210.12181981],
#        [6285.20848893],
#        [4327.74363122],
#        [4389.75049337],
#        [1304.54368466],
#        [5290.79222507],
#        [5499.56985529],
#        [4530.94308369],
#        [5031.20902191],
#        [7317.77267668],
#        [5566.95652338],
#        [6865.13619596],
#        [8083.13749153],
#        [7417.62386439],
#        [5939.11378247],
#        [1263.76311936],
#        [5696.82163705],
#        [2430.01832627],
#        [2272.93659979],
#        [2877.0361149 ],
#        [4949.04912879],
#        [5171.12732183],
#        [1220.82340558],
#        [3201.16560912],
#        [5641.40164321],
#        [2579.85502258],
#        [ 628.52668227],
#        [3915.6761231 ],
#        [7321.67718631],
#        [6352.05669589],
#        [5308.32683796],
#        [7319.72321461],
#        [5588.27423852],
#        [8533.73031331],
#        [6725.13968548],
#        [3275.3666228 ],
#        [5011.54246658],
#        [6129.6876652 ],
#        [2749.17429292],
#        [5884.79568908],
#        [6335.60392639],
#        [6088.7585166 ],
#        [5088.58421225],
#        [ 333.59898765],
#        [2877.4235166 ],
#        [4053.98110474],
#        [5482.00247473],
#        [4934.45731258],
#        [6534.06902556],
#        [5532.81616903],
#        [5164.71794125],
#        [4346.71338444],
#        [3632.46997696],
#        [2921.66912711],
#        [1596.52433317],
#        [6341.06098208],
#        [6281.83537143],
#        [2120.66199728],
#        [1741.38652861],
#        [5069.68660725],
#        [3125.68371786],
#        [3688.25284575],
#        [6909.17193894],
#        [6002.46181973],
#        [2927.01684821],
#        [5770.0466268 ],
#        [8839.86795341],
#        [6266.52770549],
#        [8052.80202509],
#        [4732.38524468],
#        [6666.94503687],
#        [4203.04296926],
#        [ 757.48878373],
#        [7318.53900914],
#        [6685.04443743],
#        [6025.06575852],
#        [4367.10434229],
#        [8635.31210279],
#        [1451.45192584],
#        [6450.34402124],
#        [7094.91752355],
#        [8270.32337069],
#        [5701.1325999 ],
#        [4278.50727078],
#        [4964.64957004],
#        [2028.15432487],
#        [6961.81505118],
#        [7893.68688154],
#        [2593.45786924],
#        [5596.93298809],
#        [6646.17486905],
#        [3310.39311768],
#        [1726.95363989],
#        [8146.77848996],
#        [6887.17080233],
#        [1113.18834893],
#        [5907.73778589],
#        [ 459.89979481],
#        [3472.91731644],
#        [4440.27252124],
#        [5999.5114839 ],
#        [1489.2517958 ],
#        [7867.02795385],
#        [5439.63236176],
#        [ 213.50421882],
#        [ 629.57865336],
#        [7187.94672192],
#        [4382.74830246],
#        [5864.80856511],
#        [8077.08681777],
#        [4219.65531571],
#        [5365.47021938],
#        [2601.2322385 ]])

# %%
print(f"Predict label for following example:\n{test_features.iloc[0,:]}")

#Predict a single value
predicted_value=reg_model_before_pp.predict([test_features.iloc[0,:]])[0]

print("\nPredicted label: ",predicted_value)
print("Actual label:", test_labels.iloc[0])
print("Deviation predicted from actual value: ",predicted_value-test_labels.iloc[0])
# Out:
# Predict label for following example:
# atemp          0.472846
# temp          19.366700
# yr             0.000000
# season         4.000000
# weathersit     2.000000
# mnth          10.000000
# Name: 0, dtype: float64
#
# Predicted label:  [3505.50991795]
# Actual label: cnt    3894
# Name: 0, dtype: int64
# Deviation predicted from actual value:  cnt   -388.490082
# Name: 0, dtype: float64
# c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(round(ypred[:10]-test_labels.iloc[0:10])*100000, 2)
# Out:
#            cnt
# 0  -38800000.0
# 1   -9200000.0
# 2   27700000.0
# 3  -25900000.0
# 4  -88400000.0
# 5  -17200000.0
# 6   93700000.0
# 7  -51600000.0
# 8   36500000.0
# 9  171800000.0 2

# %%
# Evaluate model

#Return Mean Absolute Error
mae = mean_absolute_error(test_labels, ypred)
print('MAE: %.3f' % mae)

#Return the coefficient of determination R^2 of the prediction.
print("R^2 value of the model: ",reg_model_before_pp.score(test_features, test_labels))
# Out:
# MAE: 1035.306
# R^2 value of the model:  0.367551008576638

# %%
#Check p-values using statsmodels
X = train_features
y = train_labels

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.289
# Method:                 Least Squares   F-statistic:                     41.62
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           2.21e-42
# Time:                        16:22:47   Log-Likelihood:                -5656.8
# No. Observations:                 600   AIC:                         1.133e+04
# Df Residuals:                     593   BIC:                         1.136e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        539.7485    577.795      0.934      0.351    -595.026    1674.523
# atemp       7068.4898   5571.522      1.269      0.205   -3873.826     1.8e+04
# temp           3.1767    123.916      0.026      0.980    -240.190     246.544
# yr          2474.9695    247.611      9.995      0.000    1988.668    2961.271
# season       296.3405    154.424      1.919      0.055      -6.943     599.624
# weathersit  -952.7746    230.135     -4.140      0.000   -1404.753    -500.796
# mnth          28.2119     49.515      0.570      0.569     -69.034     125.457
# ==============================================================================
# Omnibus:                     1045.631   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           510075.960
# Skew:                          11.075   Prob(JB):                         0.00
# Kurtosis:                     144.111   Cond. No.                     1.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
