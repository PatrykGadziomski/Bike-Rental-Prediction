# %% [markdown]
# # Task 2: Model Baseline and Data preparation
#
# **Course:** Introduction to Data Science
# **Lecturer:** Prof. Dr. Hendrik Meth
#
# **Group 2:**
# - Linus Breitenberger
# - Tristan Ruhm
# - Prarichut Poachanuan
# - Anushka Irphale
# - Patryk Gadziosmki

# %% [markdown]
# <div style="width:100%;height:30px;background-color:#E31134"></div>

# %% [markdown]
# ## 0. Importing Requirements

# %%
# importing libraries
import pandas as pd
from sklearn import linear_model
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# ## 1. Baseline linear regression model

# %%
# Loading the train and test data
train_df = pd.read_csv('../data/BikeRentalDaily_train.csv', delimiter=';')
test_df = pd.read_csv('../data/BikeRentalDaily_test.csv', delimiter=';')

# %% [markdown]
# ### 1.1. Minimal Preprocessing

# %%
# Replacing all MissingValues with the most frequent values (don't make any sense, just for the working code)
imp_most_freq = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

train_df[:] = imp_most_freq.fit_transform(train_df)
test_df[:] = imp_most_freq.fit_transform(test_df)

# %%
# 'dteday' is not neccessary and breaks the code

train_df = train_df.drop('dteday', axis=1)
test_df = test_df.drop('dteday', axis=1)

# %% [markdown]
# ### 1.2. Features/Label - Train/Test Split

# %%
# Splitting the train data into features and labels
train_features = train_df.iloc[:, :13]
train_labels = train_df.iloc[:, -1:]

# Splitting the test data into features and labels
test_features = test_df.iloc[:, :13]
test_labels = test_df.iloc[:, -1:]

# %%
# Check the split

# train_features
# train_labels
# test_features
# test_labels

# %% [markdown]
# ### 1.3. Linear Regresion

# %%
# Model building

# We use linear regression, which is a supervised learning technique 
# with usage of labeled training data.
baseline_model = linear_model.LinearRegression()

baseline_model.fit(train_features, train_labels)

print(baseline_model.coef_)
# Out:
# [[ 1.24294882e+00  3.15719720e+02  1.99436579e+03 -3.54038301e+00
#   -1.04678985e+03  1.82091578e+02 -4.71749309e+02 -7.48293456e+02
#   -1.55008874e+01  7.94676335e+03 -7.04580755e+00 -6.30206852e+02
#    9.13325512e-01]]

# %%
# Predict all test examples
baseline_pred = baseline_model.predict(test_features)
baseline_pred
# Out:
# array([[3406.9932736 ],
#        [5089.67118593],
#        [6893.58964078],
#        [2381.29972783],
#        [3495.756797  ],
#        [ 696.39473747],
#        [7629.06916376],
#        [5843.83408871],
#        [6781.57592485],
#        [5900.84318077],
#        [5367.8802674 ],
#        [7521.66103429],
#        [3392.46884844],
#        [8149.93997078],
#        [6684.35830847],
#        [7905.54699563],
#        [7412.91704975],
#        [2419.05241288],
#        [5465.43898259],
#        [7696.61069886],
#        [7510.5236049 ],
#        [4989.11532123],
#        [4176.96843099],
#        [1240.87449579],
#        [6273.7230086 ],
#        [5420.55149342],
#        [5942.6946315 ],
#        [4730.3594732 ],
#        [7547.89727355],
#        [5307.62372381],
#        [6138.19940021],
#        [7362.78098889],
#        [7256.54392756],
#        [5573.02496653],
#        [1283.71452962],
#        [5776.50021622],
#        [2670.1314791 ],
#        [1354.34383982],
#        [2787.95457997],
#        [5331.39070204],
#        [5319.01750342],
#        [1312.92214   ],
#        [3845.41692724],
#        [5758.65625988],
#        [3064.14542642],
#        [ 417.50751082],
#        [4001.13396208],
#        [7607.88116812],
#        [6085.11076629],
#        [5033.33101601],
#        [7386.59895657],
#        [5583.14178395],
#        [8405.85440424],
#        [7174.66731066],
#        [2313.54021877],
#        [4781.99906373],
#        [5849.09394172],
#        [2433.60073023],
#        [6340.24783166],
#        [6841.25086392],
#        [5715.26104484],
#        [4665.00244   ],
#        [ 349.95289919],
#        [2674.6814298 ],
#        [3375.4932653 ],
#        [5579.71957619],
#        [4512.97096488],
#        [6177.04784938],
#        [5831.53575009],
#        [4419.90354459],
#        [4307.86006524],
#        [4833.54575303],
#        [2786.01994726],
#        [1196.69934752],
#        [6523.88752247],
#        [6843.93151443],
#        [1721.91247812],
#        [2632.07895095],
#        [4871.41037271],
#        [2351.85900698],
#        [3241.97825563],
#        [6447.44113096],
#        [6104.52776787],
#        [3064.00513996],
#        [5095.6853487 ],
#        [8573.27768341],
#        [6639.44619453],
#        [7765.43261775],
#        [4551.82108869],
#        [6407.47040006],
#        [3546.4055051 ],
#        [ 567.98552327],
#        [8512.45906862],
#        [6379.49335615],
#        [6107.47418592],
#        [4297.30275487],
#        [8611.4139927 ],
#        [1357.16641434],
#        [6949.04050155],
#        [7130.63736121],
#        [8051.66708168],
#        [5750.97004308],
#        [3874.32132819],
#        [3706.59897021],
#        [3150.36840066],
#        [6522.00733828],
#        [7333.62800602],
#        [2442.33918981],
#        [5488.79735983],
#        [6921.84213645],
#        [3588.86611712],
#        [2794.80943398],
#        [8279.44488877],
#        [7318.3247926 ],
#        [1001.925615  ],
#        [5363.90302972],
#        [1134.71916107],
#        [2802.27015174],
#        [4273.11003147],
#        [5600.90138807],
#        [1609.72407134],
#        [7830.30438481],
#        [5273.88316598],
#        [ 476.35466192],
#        [ 866.30400907],
#        [6939.90160377],
#        [3375.88287532],
#        [5804.94524098],
#        [9167.6333945 ],
#        [3205.69615864],
#        [5145.04314099],
#        [2181.8590177 ]])

# %%
# Visualize the output
plt.figure(figsize=(14,6))
plt.plot(test_labels)
plt.plot(baseline_pred)

# %%
print(f"Predict label for following example:\n{test_features.iloc[0,:]}")

#Predict a single value
predicted_value = baseline_model.predict([test_features.iloc[0,:]])[0]

print("\nPredicted label: ",predicted_value)
print("Actual label:", test_labels.iloc[0])
print("Deviation predicted from actual value: ",predicted_value - test_labels.iloc[0])
# Out:
# Predict label for following example:
# instant       299.000000
# season          4.000000
# yr              0.000000
# mnth           10.000000
# holiday         0.000000
# weekday         3.000000
# workingday      1.000000
# weathersit      2.000000
# temp           19.366700
# atemp           0.472846
# hum           108.062550
# windspeed       0.148642
# leaflets      605.000000
# Name: 0, dtype: float64
#
# Predicted label:  [3406.9932736]
# Actual label: cnt    3894
# Name: 0, dtype: int64
# Deviation predicted from actual value:  cnt   -487.006726
# Name: 0, dtype: float64
# c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(round(baseline_pred[:10] - test_labels.iloc[0:10])*100000, 2)
# Out:
#            cnt
# 0  -48700000.0
# 1  -84600000.0
# 2  126500000.0
# 3  -92900000.0
# 4 -125200000.0
# 5  -75400000.0
# 6   58900000.0
# 7  -93400000.0
# 8  166300000.0
# 9  156900000.0 2

# %% [markdown]
# ### 1.4. Evaluate Baseline model

# %%
# Evaluate model

#Return Mean Absolute Error -> Loss: The beste Value is 0.0
mae = mean_absolute_error(test_labels, baseline_pred)
print('MAE: %.3f' % mae)

#Return the coefficient of determination R^2 of the prediction -> Score: best possible value is 1.0
print("R^2 value of the model: ",baseline_model.score(test_features, test_labels))
# Out:
# MAE: 1054.862
# R^2 value of the model:  0.4001965370904248

# %% [markdown]
# ## 2. Preprocessing

# %%
# Loading the train and test data
train_df = pd.read_csv('../data/BikeRentalDaily_train.csv', delimiter=';')
test_df = pd.read_csv('../data/BikeRentalDaily_test.csv', delimiter=';')

# %% [markdown]
# ### 2.1. Train Data Preprocessing

# %%
#hum has to many outliers
print("Hum Outliers: ", len(train_df[train_df["hum"] > 100])) # drop / don't use later
print("Windspeed Outliers: ", len(train_df[train_df["windspeed"] < 0]))
# Out:
# Hum Outliers:  229
# Windspeed Outliers:  4

# %%
#replacing outliers of windspeed with the median 
for i in train_df['windspeed']:
    if i < 0:
        train_df['windspeed'] = train_df['windspeed'].replace(i, train_df['windspeed'].median())

# %%
#replace missing values of season via dteday
for i in train_df['season']:
    if np.isnan(i):
        for j in train_df['dteday']:
            if j > '20.12.' and  j < '21.03.':
                train_df['season'] = train_df['season'].replace(i, 1)
            if j > '20.03.' and  j <'21.06.':
                train_df['season'] = train_df['season'].replace(i, 2)
            if j > '20.06.' and  j <'21.09.':
                train_df['season'] = train_df['season'].replace(i, 3)
            if j > '20.09.' and  j <'21.12.':
                train_df['season'] = train_df['season'].replace(i, 4)

# %%
train_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0      154  03.06.2011     2.0   0     6        0        5           1
# 1      685  15.11.2012     4.0   1    11        0        4           1
# 2      368  03.01.2012     1.0   1     1        0        2           1
# 3      472  16.04.2012     2.0   1     4        1        1           0
# 4      442  17.03.2012     1.0   1     3        0       -1           0
#
#    weathersit     temp     atemp        hum  windspeed  leaflets  \
# 0           1  24.8000  0.587133   53.12505   0.253121       991
# 1           2  12.8667  0.324492   93.06255   0.152987       601
# 2           1   6.0000  0.126275   66.18750   0.365671       549
# 3           1  26.5667  0.614925   84.25005   0.284829       740
# 4           2  20.5667  0.505046  113.37495   0.110704       773
#
#    price reduction  casual  registered   cnt
# 0                0     898        4414  5312
# 1                0     320        5125  5445
# 2                0      89        2147  2236
# 3                0    1198        5172  6370
# 4                1    3155        4681  7836

# %%
#replace the missing values via dteday, new order
train_df['weekday'] = pd.to_datetime(train_df['dteday'], format="%d.%M.%Y").dt.dayofweek
train_df['weekday']
# Out:
# 0      0
# 1      6
# 2      1
# 3      0
# 4      1
#       ..
# 595    2
# 596    5
# 597    3
# 598    2
# 599    2
# Name: weekday, Length: 600, dtype: int32

# %%
sns.countplot(x='weekday', data=train_df)
plt.show()

# %%
boxplot = train_df.boxplot(figsize=(15, 10))
plt.show()

# %%
# #filter the df based on the quantile (still have to figure out, which quantile percentage is the right one)
# q = train_df["casual"].quantile(0.95)

# #q = train_df.iloc[:, 2:].quantile(0.9)
# print(q)
# handeled_df = train_df[train_df['casual'] < q]

# %%
# boxplot = handeled_df.boxplot(figsize=(15, 10))
# plt.show()

# %%
# q = handeled_df["casual"].quantile(0.959)

# #q = train_df.iloc[:, 2:].quantile(0.9)
# print(q)
# handeled_df_2 = handeled_df[handeled_df['casual'] < q]

# %%
# boxplot = handeled_df_2.boxplot(figsize=(15, 10))
# plt.show()

# %%
# feature_handeled_df = handeled_df.iloc[:, :15]
# feature_handeled_df.head()

# %%
# # histogram plot
# hist = feature_handeled_df.hist(bins=20,figsize=(10, 10))
# # windspeed seems to be skewed, so we will normalize this feature

# %%
pt = PowerTransformer(standardize=False)
trans_temp= pt.fit_transform(np.array(train_df['windspeed'].array.reshape(-1, 1)))


train_df['windspeed']=trans_temp
hist = train_df['windspeed'].hist(bins=20,figsize=(10, 10))

# %%
index_names = train_df[ train_df['cnt'] > 20000 ].index 
# drop these row indexes 
# from dataFrame 
train_df = train_df.drop(index_names)

# %%
train_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        154  03.06.2011     2.0   0     6        0        0           1
# 1        685  15.11.2012     4.0   1    11        0        6           1
# 2        368  03.01.2012     1.0   1     1        0        1           1
# 3        472  16.04.2012     2.0   1     4        1        0           0
# 4        442  17.03.2012     1.0   1     3        0        1           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 595       78  19.03.2011     1.0   0     3        0        2           0
# 596       81  22.03.2011     1.0   0     3        0        5           1
# 597      377  12.01.2012     1.0   1     1        0        3           1
# 598      299  26.10.2011     4.0   0    10        0        2           1
# 599      497  11.05.2012     2.0   1     5        0        2           1
#
#      weathersit     temp     atemp        hum  windspeed  leaflets  \
# 0             1  24.8000  0.587133   53.12505   0.165133       991
# 1             2  12.8667  0.324492   93.06255   0.116416       601
# 2             1   6.0000  0.126275   66.18750   0.204408       549
# 3             1  26.5667  0.614925   84.25005   0.177579       740
# 4             2  20.5667  0.505046  113.37495   0.090391       773
# ..          ...      ...       ...        ...        ...       ...
# 595           1  18.9000  0.466525   56.87505   0.205139      1022
# 596           1  17.6667  0.440642   93.68745   0.153348       551
# 597           2  15.3000  0.381938  120.43755   0.131680       520
# 598           2  19.3667  0.472846  108.06255   0.113914       605
# 599           1  21.3333  0.520833   54.06255   0.158289       570
#
#      price reduction  casual  registered   cnt
# 0                  0     898        4414  5312
# 1                  0     320        5125  5445
# 2                  0      89        2147  2236
# 3                  0    1198        5172  6370
# 4                  1    3155        4681  7836
# ..               ...     ...         ...   ...
# 595                1    1424        1693  3117
# 596                0     460        2243  2703
# 597                0     269        3828  4097
# 598                0     404        3490  3894
# 599                1    1319        5711  7030
#
# [596 rows x 18 columns]

# %%
train_df['cnt'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 2.2. Test Data Preprocessing

# %%
#Again, alot of hum values are over 100, so we have some outliers here
# Fix this outliers?
print(len(test_df[test_df["hum"] > 100]))
# Out:
# 45

# %%
for i in test_df['season']:
    if np.isnan(i):
        for j in test_df['dteday']:
            if j > '20.12.' and  j < '21.03.':
                test_df['season'] = test_df['season'].replace(i, 1)
            if j > '20.03.' and  j <'21.06.':
                test_df['season'] = test_df['season'].replace(i, 2)
            if j > '20.06.' and  j <'21.09.':
                test_df['season'] = test_df['season'].replace(i, 3)
            if j > '20.09.' and  j <'21.12.':
                test_df['season'] = test_df['season'].replace(i, 4)

test_df['weekday'] = pd.to_datetime(test_df['dteday'], format="%d.%M.%Y").dt.dayofweek

# %%
boxplot = test_df.boxplot(figsize=(15, 10))
plt.show()

# %%
feature_test_df = test_df.iloc[:, :15]
feature_test_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0      299  26.10.2011     4.0   0    10        0        2           1
# 1      458  02.04.2012     2.0   1     4        0        0           1
# 2      687  17.11.2012     4.0   1    11        0        1           0
# 3      346  12.12.2011     4.0   0    12        0        2           1
# 4      291  18.10.2011     4.0   0    10        0        1           1
#
#    weathersit     temp     atemp        hum  windspeed  leaflets  \
# 0           2  19.3667  0.472846  108.06255   0.148642       605
# 1           1  17.3565  0.427513   75.65220   0.312139       518
# 2           1  13.0000  0.326383   81.81255   0.179729       766
# 3           1   9.5333  0.270196        NaN   0.063450       739
# 4           2  21.3000  0.522721  105.25005   0.110087       463
#
#    price reduction
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
hist = feature_test_df.hist(bins=12,figsize=(10, 10))

# %%
trans_windspeed= pt.fit_transform(np.array(feature_test_df['windspeed'].array.reshape(-1, 1)))

feature_test_df['windspeed ptransformed']=trans_windspeed
test_df['windspeed'] = feature_test_df['windspeed ptransformed']
hist = test_df['windspeed'].hist(bins=20,figsize=(10, 10))

# %%
test_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        299  26.10.2011     4.0   0    10        0        2           1
# 1        458  02.04.2012     2.0   1     4        0        0           1
# 2        687  17.11.2012     4.0   1    11        0        1           0
# 3        346  12.12.2011     4.0   0    12        0        2           1
# 4        291  18.10.2011     4.0   0    10        0        1           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 127      426  01.03.2012     1.0   1     3        0        6           1
# 128      547  30.06.2012     3.0   1     6        0        0           0
# 129      271  28.09.2011     4.0   0     9        0        4           1
# 130      180  29.06.2011     3.0   0     6        0        5           1
# 131      387  22.01.2012     1.0   1     1        0        6           0
#
#      weathersit     temp     atemp        hum  windspeed  leaflets  \
# 0             2  19.3667  0.472846  108.06255   0.120161       605
# 1             1  17.3565  0.427513   75.65220   0.206779       518
# 2             1  13.0000  0.326383   81.81255   0.139545       766
# 3             1   9.5333  0.270196        NaN   0.057694       739
# 4             2  21.3000  0.522721  105.25005   0.093734       463
# ..          ...      ...       ...        ...        ...       ...
# 127           1  19.4333  0.475371   92.31255   0.166143       777
# 128           1  30.6000  0.687508   90.18750   0.128105       981
# 129           2  25.4000  0.575158  127.31250   0.120153       577
# 130           1  29.1333  0.654688   74.68755   0.183799       585
# 131           2   6.5000  0.162250  119.43750   0.151148       651
#
#      price reduction  casual  registered   cnt
# 0                  0     404        3490  3894
# 1                  0    1208        4728  5936
# 2                  0    1313        4316  5629
# 3                  0     143        3167  3310
# 4                  0     637        4111  4748
# ..               ...     ...         ...   ...
# 127                0     325        4665  4990
# 128                0    1455        4232  5687
# 129                0     480        3427  3907
# 130                0     848        4377  5225
# 131                0     196        1781  1977
#
# [132 rows x 18 columns]

# %% [markdown]
# ## 3. Feature Selection

# %%
# 'instant' and 'dteday' are not neccessary
train_df = train_df.drop('dteday', axis=1).drop('instant', axis=1).drop('hum', axis=1)
test_df = test_df.drop('dteday', axis=1).drop('instant', axis=1).drop('hum', axis=1)

# %%
#calculate correlations between all features of your data frame (see Exploration lab)
train_corr = train_df.corr()
print(train_corr)

# Displaying correlations as a heatmap / correlation matrix 
train_corr.style.background_gradient(cmap='coolwarm')
# Out:
#                    season        yr      mnth   holiday   weekday  workingday  \
# season           1.000000 -0.033477  0.685960 -0.001416 -0.009581   -0.005619
# yr              -0.033477  1.000000 -0.028837  0.021979 -0.025109    0.008882
# mnth             0.685960 -0.028837  1.000000  0.035441  0.017818   -0.020155
# holiday         -0.001416  0.021979  0.035441  1.000000 -0.062369   -0.258964
# weekday         -0.009581 -0.025109  0.017818 -0.062369  1.000000   -0.002467
# workingday      -0.005619  0.008882 -0.020155 -0.258964 -0.002467    1.000000
# weathersit       0.032999 -0.039531  0.072770 -0.022563  0.043374    0.067185
# temp             0.316933  0.030209  0.207435 -0.023457 -0.028104    0.052450
# atemp            0.319582  0.028998  0.213059 -0.027784 -0.022056    0.050782
# windspeed       -0.212026 -0.021451 -0.257743  0.015885  0.019703    0.001871
# leaflets        -0.007392 -0.080441 -0.076208 -0.048116  0.005699    0.012017
# price reduction -0.010487 -0.008500 -0.026320 -0.046430  0.055231    0.032606
# casual           0.194905  0.228653  0.124286  0.065640 -0.048611   -0.528286
# registered       0.346030  0.579835  0.258215 -0.113882 -0.058458    0.308867
# cnt              0.348816  0.549341  0.252699 -0.068206 -0.064559    0.059241
#
#                  weathersit      temp     atemp  windspeed  leaflets  \
# season             0.032999  0.316933  0.319582  -0.212026 -0.007392
# yr                -0.039531  0.030209  0.028998  -0.021451 -0.080441
# mnth               0.072770  0.207435  0.213059  -0.257743 -0.076208
# holiday           -0.022563 -0.023457 -0.027784   0.015885 -0.048116
# weekday            0.043374 -0.028104 -0.022056   0.019703  0.005699
# workingday         0.067185  0.052450  0.050782   0.001871  0.012017
# weathersit         1.000000 -0.095019 -0.095395   0.048243 -0.020918
# temp              -0.095019  1.000000  0.990331  -0.159180  0.011679
# atemp             -0.095395  0.990331  1.000000  -0.186834  0.009075
# windspeed          0.048243 -0.159180 -0.186834   1.000000 -0.024670
# leaflets          -0.020918  0.011679  0.009075  -0.024670  1.000000
# price reduction    0.036114 -0.020604 -0.016678   0.039772  0.090156
# casual            -0.250677  0.548916  0.549816  -0.174820 -0.012519
# registered        -0.259409  0.539667  0.544117  -0.238076 -0.044785
# cnt               -0.299036  0.631948  0.635856  -0.254612 -0.040583
#
#                  price reduction    casual  registered       cnt
# season                 -0.010487  0.194905    0.346030  0.348816
# yr                     -0.008500  0.228653    0.579835  0.549341
# mnth                   -0.026320  0.124286    0.258215  0.252699
# holiday                -0.046430  0.065640   -0.113882 -0.068206
# weekday                 0.055231 -0.048611   -0.058458 -0.064559
# workingday              0.032606 -0.528286    0.308867  0.059241
# weathersit              0.036114 -0.250677   -0.259409 -0.299036
# temp                   -0.020604  0.548916    0.539667  0.631948
# atemp                  -0.016678  0.549816    0.544117  0.635856
# windspeed               0.039772 -0.174820   -0.238076 -0.254612
# leaflets                0.090156 -0.012519   -0.044785 -0.040583
# price reduction         1.000000 -0.002427    0.003943  0.002306
# casual                 -0.002427  1.000000    0.383236  0.667830
# registered              0.003943  0.383236    1.000000  0.943422
# cnt                     0.002306  0.667830    0.943422  1.000000
# <style type="text/css">
# #T_449a3_row0_col0, #T_449a3_row1_col1, #T_449a3_row2_col2, #T_449a3_row3_col3, #T_449a3_row4_col4, #T_449a3_row5_col5, #T_449a3_row6_col6, #T_449a3_row7_col7, #T_449a3_row8_col8, #T_449a3_row9_col9, #T_449a3_row10_col10, #T_449a3_row11_col11, #T_449a3_row12_col12, #T_449a3_row13_col13, #T_449a3_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col1, #T_449a3_row14_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_449a3_row0_col3, #T_449a3_row5_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col4, #T_449a3_row4_col1, #T_449a3_row9_col1, #T_449a3_row9_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_449a3_row0_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_449a3_row0_col7, #T_449a3_row2_col13, #T_449a3_row13_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_449a3_row0_col8, #T_449a3_row2_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_449a3_row0_col9, #T_449a3_row1_col4, #T_449a3_row1_col11, #T_449a3_row6_col1, #T_449a3_row12_col6, #T_449a3_row14_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col10, #T_449a3_row11_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col11, #T_449a3_row7_col4, #T_449a3_row9_col14, #T_449a3_row13_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_449a3_row0_col12 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_449a3_row0_col13 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_449a3_row0_col14 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_449a3_row1_col0, #T_449a3_row10_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col2, #T_449a3_row1_col8, #T_449a3_row4_col14, #T_449a3_row5_col7, #T_449a3_row6_col12 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_449a3_row1_col6, #T_449a3_row5_col8, #T_449a3_row6_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col9, #T_449a3_row5_col2, #T_449a3_row6_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col10, #T_449a3_row2_col9, #T_449a3_row3_col4, #T_449a3_row3_col11, #T_449a3_row5_col3, #T_449a3_row5_col12, #T_449a3_row6_col13, #T_449a3_row6_col14, #T_449a3_row9_col0, #T_449a3_row9_col2, #T_449a3_row9_col7, #T_449a3_row9_col8, #T_449a3_row10_col1, #T_449a3_row12_col5, #T_449a3_row14_col4, #T_449a3_row14_col6, #T_449a3_row14_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_449a3_row1_col12 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_449a3_row1_col13 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_449a3_row1_col14 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_449a3_row2_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_449a3_row2_col1, #T_449a3_row13_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_449a3_row2_col3, #T_449a3_row3_col2, #T_449a3_row9_col12, #T_449a3_row11_col14 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_449a3_row2_col4, #T_449a3_row5_col11, #T_449a3_row6_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_449a3_row2_col5, #T_449a3_row12_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_449a3_row2_col6, #T_449a3_row12_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_449a3_row2_col7, #T_449a3_row4_col12 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_449a3_row2_col8, #T_449a3_row10_col12 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_449a3_row2_col10, #T_449a3_row13_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_449a3_row2_col11, #T_449a3_row9_col13, #T_449a3_row13_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_449a3_row2_col14 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_449a3_row3_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col1, #T_449a3_row4_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col5, #T_449a3_row3_col14 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col6, #T_449a3_row10_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col7, #T_449a3_row3_col13, #T_449a3_row13_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col9, #T_449a3_row9_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col10, #T_449a3_row8_col11, #T_449a3_row13_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_449a3_row3_col12, #T_449a3_row6_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_449a3_row4_col0, #T_449a3_row10_col3, #T_449a3_row10_col8, #T_449a3_row11_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col2, #T_449a3_row4_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col5, #T_449a3_row9_col5, #T_449a3_row11_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_449a3_row4_col6, #T_449a3_row6_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_449a3_row4_col7, #T_449a3_row11_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col10, #T_449a3_row6_col11, #T_449a3_row7_col9, #T_449a3_row9_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_449a3_row4_col13, #T_449a3_row7_col6, #T_449a3_row8_col6, #T_449a3_row11_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_449a3_row5_col0, #T_449a3_row10_col0, #T_449a3_row10_col13, #T_449a3_row11_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_449a3_row5_col1, #T_449a3_row5_col10, #T_449a3_row7_col10, #T_449a3_row8_col10, #T_449a3_row9_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_449a3_row5_col4, #T_449a3_row6_col7, #T_449a3_row6_col10, #T_449a3_row8_col9 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_449a3_row5_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_449a3_row5_col13 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_449a3_row5_col14 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_449a3_row6_col4, #T_449a3_row8_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_449a3_row6_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_449a3_row7_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_449a3_row7_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_449a3_row7_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_449a3_row7_col3, #T_449a3_row8_col3, #T_449a3_row10_col9, #T_449a3_row11_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_449a3_row7_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_449a3_row7_col8, #T_449a3_row8_col7 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_449a3_row7_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_449a3_row7_col12, #T_449a3_row8_col12 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_449a3_row7_col13 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_449a3_row7_col14 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_449a3_row8_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_449a3_row8_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_449a3_row8_col4, #T_449a3_row12_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_449a3_row8_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_449a3_row8_col13 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_449a3_row8_col14 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_449a3_row9_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_449a3_row10_col2, #T_449a3_row11_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }

# %%
#calculate correlations of features to label
train_df_corr_label = train_df.iloc[:, :].corr()["cnt"]
train_df_corr_label
# Out:
# season             0.348816
# yr                 0.549341
# mnth               0.252699
# holiday           -0.068206
# weekday           -0.064559
# workingday         0.059241
# weathersit        -0.299036
# temp               0.631948
# atemp              0.635856
# windspeed         -0.254612
# leaflets          -0.040583
# price reduction    0.002306
# casual             0.667830
# registered         0.943422
# cnt                1.000000
# Name: cnt, dtype: float64

# %%
# All the preprocessed features
train_corr_high = train_df

# The nine features with the highest correlation with count
train_corr_high = train_df[train_df_corr_label.abs().sort_values(ascending=False).index[:12]]

# The four features with the highest correlation with count -------> (favorit)
# train_corr_high = train_df[train_df_corr_label.abs().sort_values(ascending=False).index[:7]]

train_corr_high
# Out:
#       cnt  registered  casual     atemp     temp  yr  season  weathersit  \
# 0    5312        4414     898  0.587133  24.8000   0     2.0           1
# 1    5445        5125     320  0.324492  12.8667   1     4.0           2
# 2    2236        2147      89  0.126275   6.0000   1     1.0           1
# 3    6370        5172    1198  0.614925  26.5667   1     2.0           1
# 4    7836        4681    3155  0.505046  20.5667   1     1.0           2
# ..    ...         ...     ...       ...      ...  ..     ...         ...
# 595  3117        1693    1424  0.466525  18.9000   0     1.0           1
# 596  2703        2243     460  0.440642  17.6667   0     1.0           1
# 597  4097        3828     269  0.381938  15.3000   1     1.0           2
# 598  3894        3490     404  0.472846  19.3667   0     4.0           2
# 599  7030        5711    1319  0.520833  21.3333   1     2.0           1
#
#      windspeed  mnth  holiday  weekday
# 0     0.165133     6        0        0
# 1     0.116416    11        0        6
# 2     0.204408     1        0        1
# 3     0.177579     4        1        0
# 4     0.090391     3        0        1
# ..         ...   ...      ...      ...
# 595   0.205139     3        0        2
# 596   0.153348     3        0        5
# 597   0.131680     1        0        3
# 598   0.113914    10        0        2
# 599   0.158289     5        0        2
#
# [596 rows x 12 columns]

# %% [markdown]
# ## 4. New Linear Regression Model

# %% [markdown]
# ### 4.1. Split

# %%
# Splitting the train data into features and labels
train_features = train_corr_high.iloc[:, 3:]
train_labels = train_corr_high.iloc[:, :1]

# Splitting the test data into features and labels
test_features = test_df.loc[:, ['atemp', 'temp', 'yr', 'season', 'weathersit', 'windspeed', 'mnth', 'holiday', 'weekday']]
test_labels = test_df.iloc[:, -1:]

# train_features
# train_labels
# test_features
# test_labels

# %% [markdown]
# ### 4.2. Linear Regression

# %%
# Model building

# We use linear regression, which is a supervised learning technique 
# with usage of labeled training data.
model = linear_model.LinearRegression()

model.fit(train_features, train_labels)

print(model.coef_)
# Out:
# [[ 3736.98146289    54.08504288  2019.01132544   260.6128755
#    -817.58793035 -4642.77643883    26.22718668  -816.82659147
#     -28.10749399]]

# %%
# Predict all test examples
pred = model.predict(test_features)
pred
# Out:
# array([[3602.65169532],
#        [5136.60073722],
#        [5511.91752526],
#        [3473.57832692],
#        [4044.40131597],
#        [1485.8338993 ],
#        [7171.45497229],
#        [5924.05975209],
#        [5351.19745761],
#        [5801.79584598],
#        [4970.43795467],
#        [7124.33079117],
#        [2268.88387695],
#        [7321.97647395],
#        [6219.44190422],
#        [7267.99469705],
#        [7327.93079788],
#        [3346.78901905],
#        [5063.30781741],
#        [7523.99438308],
#        [5587.98693274],
#        [3773.34089914],
#        [4332.84845431],
#        [1511.46477684],
#        [5083.71119317],
#        [5124.85877172],
#        [4327.67548656],
#        [4583.41916231],
#        [6813.28773684],
#        [5033.19631063],
#        [6605.75040765],
#        [7467.6630504 ],
#        [6585.86400001],
#        [5005.58183597],
#        [1652.51145759],
#        [4782.26326618],
#        [2597.6437422 ],
#        [2055.2419907 ],
#        [3057.67073084],
#        [4561.92561998],
#        [4851.89488846],
#        [1408.87361799],
#        [3170.62107904],
#        [5437.60024645],
#        [2451.80182596],
#        [1141.02099869],
#        [3697.20681109],
#        [6769.6193602 ],
#        [5535.22381114],
#        [4278.53670306],
#        [6373.18945063],
#        [5327.84227673],
#        [7142.78731556],
#        [6207.75506169],
#        [3391.3156767 ],
#        [4632.32810776],
#        [5282.72349707],
#        [2591.50290064],
#        [5872.18127848],
#        [5858.59686625],
#        [5865.01475184],
#        [4574.64279022],
#        [ 962.67168358],
#        [2295.38807396],
#        [3855.1193823 ],
#        [5279.91514738],
#        [4485.66155819],
#        [5897.44485324],
#        [4649.48275886],
#        [4083.49921376],
#        [4053.13940943],
#        [3337.84404341],
#        [3356.47674435],
#        [1738.0240009 ],
#        [5963.34753398],
#        [5921.44421558],
#        [2641.46415314],
#        [1796.59491253],
#        [4519.10661891],
#        [2380.28985065],
#        [3896.36867439],
#        [6412.67223075],
#        [5574.39109695],
#        [2973.6660561 ],
#        [5367.54401174],
#        [7977.81679212],
#        [5615.61547923],
#        [7268.35359984],
#        [4648.33172142],
#        [5771.37533629],
#        [3687.75938887],
#        [1266.65377708],
#        [6426.48411849],
#        [6306.34409468],
#        [5101.15405496],
#        [3895.15388448],
#        [7763.84347322],
#        [1660.32635332],
#        [5528.76579377],
#        [6340.58659105],
#        [7698.02189879],
#        [5355.47339709],
#        [3967.98658278],
#        [4482.68511068],
#        [1914.55688543],
#        [6385.17371904],
#        [7285.38183361],
#        [2838.85911074],
#        [5214.12164231],
#        [5928.34715109],
#        [3195.26769906],
#        [1309.40923147],
#        [7510.86191256],
#        [6717.32754711],
#        [1435.59475634],
#        [5303.83983441],
#        [ 860.68046608],
#        [2431.80263581],
#        [4425.87964313],
#        [5503.34064439],
#        [1912.84227429],
#        [7258.20267559],
#        [5177.13457491],
#        [ 674.81209616],
#        [1200.58327721],
#        [6235.67661516],
#        [3168.87898794],
#        [5160.94929261],
#        [7502.80457247],
#        [4228.89808379],
#        [4882.7087637 ],
#        [2490.89876806]])

# %% [markdown]
# ### 4.3. Evaluation

# %%
# Visualize the output
plt.figure(figsize=(14,6))
plt.plot(test_labels)
plt.plot(pred)

# %%
print(f"Predict label for following example:\n{test_features.iloc[0,:]}")

#Predict a single value
predicted_value = model.predict([test_features.iloc[0,:]])[0]

print("\nPredicted label: ",predicted_value)
print("Actual label:", test_labels.iloc[0])
print("Deviation predicted from actual value: ", predicted_value - test_labels.iloc[0])
# Out:
# Predict label for following example:
# atemp          0.472846
# temp          19.366700
# yr             0.000000
# season         4.000000
# weathersit     2.000000
# windspeed      0.120161
# mnth          10.000000
# holiday        0.000000
# weekday        2.000000
# Name: 0, dtype: float64
#
# Predicted label:  [3602.65169532]
# Actual label: cnt    3894
# Name: 0, dtype: int64
# Deviation predicted from actual value:  cnt   -291.348305
# Name: 0, dtype: float64
# c:\Users\Akira\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(round(pred[:10] - test_labels.iloc[0:10])*100000, 2)
# Out:
#            cnt
# 0  -29100000.0
# 1  -79900000.0
# 2  -11700000.0
# 3   16400000.0
# 4  -70400000.0
# 5    3600000.0
# 6   13100000.0
# 7  -85400000.0
# 8   23200000.0
# 9  147000000.0 2

# %%
# Evaluate model

#Return Mean Absolute Error -> Loss: The beste Value is 0.0
mae = mean_absolute_error(test_labels, pred)
print('MAE: %.3f' % mae)

#Return the coefficient of determination R^2 of the prediction -> Score: best possible value is 1.0
print("R^2 value of the model: ", model.score(test_features, test_labels))
# Out:
# MAE: 931.208
# R^2 value of the model:  0.36813591795729284
